# %%
import pandas as pd

df = pd.read_csv("./results.csv")
df.head()
df = df[df["Leaf Size"] != 500]
df.columns = ['Airport', 'Leaf Size', 'Linear', 'Proposed', 'Lund']

# %%
# %matplotlib inline

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)



np.random.seed(sum(map(ord, "distributions")))
airports = {"eddt": "Berlin Tegel Airport", 
            "egll": "Heathrow Airport", 
            "yssy": "Sydney Airport", 
            "zbaa": "Beijing Capital International Airport", 
            "lebl": "Barcelona–El Prat Airport", 
            "lfpg": "Charles de Gaulle Airport", 
            "limc": "Milan-Malpensa Airport"}

ylims = [(3.7,4.1), (3, 3.35), (2.55, 2.8), (3.2, 4), (2.1, 2.6), (3.5, 3.9), (3.7, 3.95)]
for i, code in enumerate(["eddt", "egll", "yssy", "zbaa", "lebl", "lfpg", "limc"]): 
    df.loc[df['Airport'] == code].plot(title=airports[code], legend=False, kind="bar", x="Leaf Size", ylim=ylims[i], fontsize=16)
# Out:
# /Users/pablo/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /Users/pablo/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-3-425deb1f82d7> in <module>()
#      19 ylims = [(3.7,4.1), (3, 3.35), (2.55, 2.8), (3.2, 4), (2.1, 2.6), (3.5, 3.9), (3.7, 3.95)]
#      20 for i, code in enumerate(["eddt", "egll", "yssy", "zbaa", "lebl", "lfpg", "limc"]):
# ...

# %%
arr = np.array([[0.913, 0.833, 0.357, 0.230], [0.620, 0.372, 0.233, 0.206], [0.620, 0.389, 0.357, 0.340]]).T
df_mkv = pd.DataFrame(arr, index=[2500, 1250, 500, 250], columns=["Linear", "Proposed", "Lund"])
df_mkv.plot(xticks=[2500, 1250, 500, 250], title="65N Radiation RMSE", lw=3, logx=True, fontsize=16)

# %%
LEBL = np.array([[3.505, 2.884, 2.543, 2.402, 2.368, 2.361], 
                 [3.370, 2.639, 2.500, 2.386, 2.343, 2.348], 
                 [3.141, 2.597, 2.600, 2.573, 2.553, 2.555]]).T

ZBAA = np.array([[5.963, 4.772, 4.203, 3.911, 3.689, 3.679], 
                 [5.563, 4.399, 3.880, 3.635, 3.549, 3.551], 
                 [5.163, 4.181, 3.927, 3.921, 3.923, 3.922]]).T

LFPG = np.array([[4.708, 4.073, 3.898, 3.797, 3.764, 3.767], 
                 [4.615, 4.078, 3.897, 3.765, 3.730, 3.737], 
                 [4.513, 4.070, 3.916, 3.885, 3.880, 3.889]]).T

EDDT = np.array([[5.166, 4.452, 4.275, 4.147, 4.119, 4.120], 
                 [4.973, 4.362, 4.232, 4.094, 4.074, 4.076], 
                 [4.854, 4.374, 4.266, 4.157, 4.137, 4.138]]).T


df_mkv = pd.DataFrame(ZBAA, index=[2500, 1000, 500, 250, 100, 50], columns=["Linear", "Proposed", "Lund"])
df_mkv.plot(xticks=[2500, 1250, 500, 250, 100, 50], title="Obs Temperature RMSE", lw=3, logx=True, fontsize=16)

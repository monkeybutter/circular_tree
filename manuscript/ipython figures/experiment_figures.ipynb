# %%
import pandas as pd

df = pd.read_csv("/Users/pablo/Desktop/results.csv")
df.head()
df = df[df["Leaf Size"] != 500]
df
# Out:
#    Airport  Leaf Size   Classic  Proposed      Lund
# 0     eddt         50  3.844653  3.822736  3.993885
# 1     eddt        100  3.868627  3.854717  3.989427
# 2     eddt        250  4.012943  3.981442  4.055566
# 4     egll         50  3.094903  3.053108  3.260291
# 5     egll        100  3.146717  3.083676  3.227443
# 6     egll        250  3.257100  3.241268  3.249836
# 8     yssy         50  2.634169  2.613693  2.743589
# 9     yssy        100  2.625394  2.601482  2.699054
# 10    yssy        250  2.669892  2.680471  2.726951
# 12    zbaa         50  3.492834  3.354012  3.843093
# 13    zbaa        100  3.540228  3.374236  3.851074
# 14    zbaa        250  3.841755  3.524530  3.864088
# 16    lebl         50  2.234422  2.202155  2.561322
# 17    lebl        100  2.264347  2.232463  2.525564
# 18    lebl        250  2.345784  2.316495  2.521093
# 20    lfpg         50  3.586508  3.545265  3.842942
# 21    lfpg        100  3.595305  3.567165  3.794445
# 22    lfpg        250  3.699155  3.691096  3.766400
# 24    limc         50  3.753118  3.765067  3.864787
# 25    limc        100  3.778738  3.749643  3.819457
# 26    limc        250  3.898534  3.882720  3.848535

# %%
# %matplotlib inline

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "distributions")))
airports = {"eddt": "Berlin Tegel Airport", 
            "egll": "Heathrow Airport", 
            "yssy": "Sydney Airport", 
            "zbaa": "Beijing Capital International Airport", 
            "lebl": "Barcelona–El Prat Airport", 
            "lfpg": "Charles de Gaulle Airport", 
            "limc": "Milan-Malpensa Airport"}

ylims = [(3.7,4.1), (3, 3.35), (2.55, 2.8), (3.2, 4), (2.1, 2.6), (3.5, 3.9), (3.7, 3.95)]
for i, code in enumerate(["eddt", "egll", "yssy", "zbaa", "lebl", "lfpg", "limc"]): 
    df.loc[df['Airport'] == code].plot(title=airports[code], kind="bar", x="Leaf Size", ylim=ylims[i])
# Out:
# /Users/pablo/anaconda/envs/python3/lib/python3.4/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
